# %% [markdown]
# # github doesn't support dynamic JS...
#
#     > to view the plots go here here...
#         - http://nbviewer.jupyter.org/github/FelicianoAnthony/Python_projects/blob/master/web-scraping/br_scraping_walkthrough.ipynb

# %%
import sys
sys.path.append('/path/to/baseball_analysis.py')

# %%
import baseball_analysis as table_scraper
table_scraper = table_scraper.html_table_scraper()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2869c4ab-17c8-48ad-a763-d912e3ade303">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # EXAMPLE
#     > scraped table

# %%
df = table_scraper.scrape_batting_tables('https://www.baseball-reference.com/teams/NYM/2016.shtml')
# filter by all players under 25 who aren't pitchers and sort by home runs 
df.ix[(df['AGE'] < 25 ) & (df['POS'] != 'P')].sort_values('HR', ascending=False)
# Out:
#                                  RK POS  AGE    G   PA   AB   R   H  2B  3B  \
# NAME             TEAM_NAME YEAR
# Wilmer Flores    NYM       2016   9  CI   24  103  335  307  38  82  14   0
# Michael Conforto NYM       2016   6  LF   23  109  348  304  38  67  21   1
# Brandon Nimmo    NYM       2016  21  OF   23   32   80   73  12  20   1   0
# Gavin Cecchini   NYM       2016  24  SS   22    4    7    6   2   2   2   0
#
#                                 ...     OBP    SLG    OPS  OPS+   TB  GDP  \
# NAME             TEAM_NAME YEAR ...
# Wilmer Flores    NYM       2016 ...   0.319  0.469  0.788   110  144    9
# Michael Conforto NYM       2016 ...   0.310  0.414  0.725    94  126    6
# Brandon Nimmo    NYM       2016 ...   0.338  0.329  0.666    82   24    0
# Gavin Cecchini   NYM       2016 ...   0.429  0.667  1.095   190    4    0
#
#                                  HBP  SH  SF  IBB
# NAME             TEAM_NAME YEAR
# Wilmer Flores    NYM       2016    2   0   3    0
# Michael Conforto NYM       2016    5   0   3    2
# Brandon Nimmo    NYM       2016    1   0   0    0
# Gavin Cecchini   NYM       2016    1   0   0    0
#
# [4 rows x 27 columns]

# %% [markdown]
# # SCRAPE TEAM NAMES
#
#     > scrapes team name urls from table on main page of baseball reference
#     > helps to concat url used in function below

# %%
base_url = 'http://www.baseball-reference.com/leagues/MLB/'
year = '/2016'
team_names = table_scraper.get_team_names(base_url, year)
team_names[0:10]
# Out:
# ['/ARI',
#  '/ATL',
#  '/BAL',
#  '/BOS',
#  '/CHC',
#  '/CHW',
#  '/CIN',
#  '/CLE',
#  '/COL',
#  '/DET']

# %% [markdown]
# # DOWNLOAD TEAM BATTING TABLES TO CSVS
#
#     > can download any teams/years combination for team batting tables

# %%
#create specific team-year combinations - cwd --5 minutes/year 
base_url = 'http://www.baseball-reference.com/teams'
years_lst = ['/2012', '/2013']
ext = '.shtml'

table_scraper.create_batting_links(base_url, team_names[0:5], years_lst, ext)
# Out:
# Saving in  os.getcwd()
#
# Saved csv for team_year - ARI_2012
# Saved csv for team_year - ATL_2012
# Saved csv for team_year - BAL_2012
# Saved csv for team_year - BOS_2012
# Saved csv for team_year - CHC_2012
# Saved csv for team_year - ARI_2013
# Saved csv for team_year - ATL_2013
# Saved csv for team_year - BAL_2013
# Saved csv for team_year - BOS_2013
# Saved csv for team_year - CHC_2013

# %% [markdown]
# # CONCAT  ALL TEAM BATTING DFS
#
#     > file path must not contain sub-folders & must only have batting csvs
#     > giant dataframe

# %%
team_path = ''
df1 = table_scraper.get_player_names(team_path, stats=True)
df1.shape
# Out:
# (8531, 30)

# %% [markdown]
# # GET PLAYER NAMES FROM CSVS TO SEARCH BR FOR SALARIES
#     > file path must not contain sub-folders & must only have batting csvs
#     > concatenates all csvs and extracts all player names from all csv files

# %%
team_path = ''
player_names = table_scraper.get_player_names(team_path)
player_names[0:10]
# Out:
# ['Chris Owings ',
#  'Yasmany Tomas ',
#  'Nick Ahmed ',
#  'Rey Fuentes ',
#  'Jeremy Hazelbaker ',
#  'Jack Reinheimer ',
#  'Ildemaro Vargas ',
#  'Robbie Ray ',
#  'Shelby Miller ',
#  'Randall Delgado ']

# %% [markdown]
# # SALARY CRAWLER
#
#     > given a list of player names from batting csvs ...
#        > ...iterate through hundreds of player name urls in br player index to scrape and save salary table to csv
#            > ... takes 3-4 hours for all names in a given season

# %%
table_scraper.salary_crawl(player_names[0:5])
# Out:
# Saving in  os.getcwd()
#
# http://www.baseball-reference.com/players/a/ahmedni01.shtml
# http://www.baseball-reference.com/players/f/fuentre01.shtml
# 'NoneType' object has no attribute 'find_all' ^^  -- salary table probably missing --
# http://www.baseball-reference.com/players/h/hazelje01.shtml
# http://www.baseball-reference.com/players/o/owingch01.shtml
# http://www.baseball-reference.com/players/t/tomasya01.shtml

# %% [markdown]
# # MERGE PLAYER SALARY & TEAM BATTING DFS
#
#
#     > file paths must not contain sub-folders & must only have csvs of that type
#     > salaries dfs & team dfs indexed on team, name, year are merged and players w/o salaries are dropped

# %%
sal_path = ''
team_path = ''
table_scraper.merge_dfs(sal_path, team_path, 2016).head()
# Out:
#               NAME TEAM_NAME  YEAR  RK POS  AGE    G   PA     AB      R  \
# 0    Tyler Flowers       ATL  2016   1   C   30   83  325  281.0   27.0
# 1  Freddie Freeman       ATL  2016   2  1B   26  158  693  589.0  102.0
# 2    Jace Peterson       ATL  2016   3  2B   26  115  408  350.0   45.0
# 3        Matt Kemp       ATL  2016   6  LF   31   56  241  214.0   35.0
# 4   Ender Inciarte       ATL  2016   7  CF   25  131  578  522.0   85.0
#
#     ...       TB   GDP   HBP   SH   SF   IBB      SALARY  \
# 0   ...    118.0   3.0  11.0  0.0  4.0   1.0   2,000,000
# 1   ...    335.0  12.0  10.0  0.0  5.0  18.0  12,000,000
# 2   ...    128.0   9.0   1.0  2.0  3.0   2.0     520,500
# 3   ...    111.0   9.0   1.0  0.0  6.0   3.0  21,750,000
# 4   ...    199.0   8.0   4.0  5.0  2.0   5.0     523,000
#
#                                         position  height  weight
# 0                                        Catcher     6'4   260lb
# 1                                  First Baseman     6'5   220lb
# 2  Second Baseman, Leftfielder and Third Baseman     6'0   215lb
# 3                                     Outfielder     6'4   210lb
# 4                                     Outfielder     5'1   190lb
#
# [5 rows x 34 columns]

# %%
table_scraper.sum_stat_by_team(team_path, '2016', '2B', get_cols=True)
# Out:
# Index(['NAME', 'TEAM_NAME', 'YEAR', 'RK', 'POS', 'AGE', 'G', 'PA', 'AB', 'R',
#        'H', '2B', '3B', 'HR', 'RBI', 'SB', 'CS', 'BB', 'SO', 'BA', 'OBP',
#        'SLG', 'OPS', 'OPS+', 'TB', 'GDP', 'HBP', 'SH', 'SF', 'IBB'],
#       dtype='object')

# %% [markdown]
# # BAR GRAPH
#
#     > plot any statistics that 'make sense' to be summed by team in a bar graph -- i.e. no percentages

# %%
# in 2017, houston is the team with the most home runs
table_scraper.sum_stat_by_team(team_path, 2017, 'HR')
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0a83ef20-4afa-46ae-9d80-c85c49140b59"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("0a83ef20-4afa-46ae-9d80-c85c49140b59").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0a83ef20-4afa-46ae-9d80-c85c49140b59");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0a83ef20-4afa-46ae-9d80-c85c49140b59' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"80b01a6f-2af3-45f9-af29-d1d66dd3eb1e":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9d329234-1336-4ebe-b376-32fb681b012c","type":"Rect"},{"attributes":{"plot":{"id":"456adc8c-1328-4c6f-88b0-b6184088fb88","subtype":"Chart","type":"Plot"}},"id":"fc04c8bb-3495-4ff9-bb59-88db317183bf","type":"HelpTool"},{"attributes":{"axis_label":"Sum( Hr )","formatter":{"id":"ae607c5b-5746-4b35-a07c-38811218deb0","type":"BasicTickFormatter"},"plot":{"id":"456adc8c-1328-4c6f-88b0-b6184088fb88","subtype":"Chart","type":"Plot"},"ticker":{"id":"c251ba3a-be19-42b1-873b-91eabd0180f4","type":"BasicTicker"}},"id":"3b24e881-f538-4965-b728-a27e3e2feb26","type":"LinearAxis"},{"attributes":{"plot":{"id":"456adc8c-1328-4c6f-88b0-b6184088fb88","subtype":"Chart","type":"Plot"}},"id":"cb949597-bc07-4733-bf48-98a80d7ccca3","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"d2da02c3-8850-45c0-a545-9ac70e521e6b","type":"BoxAnnotation"},"plot":{"id":"456adc8c-1328-4c6f-88b0-b6184088fb88","subtype":"Chart","type":"Plot"}},"id":"ece3e31c-4d40-4f6b-b00f-6dc9afdbfc11","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"456adc8c-1328-4c6f-88b0-b6184088fb88","subtype":"Chart","type":"Plot"}},"id":"34087fc5-9ab4-418d-bb59-4580b1cc6f1a","type":"SaveTool"},{"attributes":{"plot":{"id":"456adc8c-1328-4c6f-88b0-b6184088fb88","subtype":"Chart","type":"Plot"}},"id":"99d3d026-ee0d-42ee-9ab8-6eb972c96210","type":"ResetTool"},{"attributes":{"plot":{"id":"456adc8c-1328-4c6f-88b0-b6184088fb88","subtype":"Chart","type":"Plot"}},"id":"14cbf08e-1ddd-4f5a-b76a-4d08103e9783","type":"PanTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d799b9a0-05b4-441d-8fdb-a4d6b864cdef","type":"Rect"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"d2da02c3-8850-45c0-a545-9ac70e521e6b","type":"BoxAnnotation"},{"attributes":{"plot":null,"text":"2017 HR summed"},"id":"dcdef278-3c19-4250-beb1-e1459faadd0e","type":"Title"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"14cbf08e-1ddd-4f5a-b76a-4d08103e9783","type":"PanTool"},{"id":"cb949597-bc07-4733-bf48-98a80d7ccca3","type":"WheelZoomTool"},{"id":"ece3e31c-4d40-4f6b-b00f-6dc9afdbfc11","type":"BoxZoomTool"},{"id":"34087fc5-9ab4-418d-bb59-4580b1cc6f1a","type":"SaveTool"},{"id":"99d3d026-ee0d-42ee-9ab8-6eb972c96210","type":"ResetTool"},{"id":"fc04c8bb-3495-4ff9-bb59-88db317183bf","type":"HelpTool"}]},"id":"5e5e53e5-ad65-4afc-b902-694145bdd147","type":"Toolbar"},{"attributes":{},"id":"ae607c5b-5746-4b35-a07c-38811218deb0","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"e58bb7ab-e808-47c5-aa86-18c669b862d8","type":"ColumnDataSource"},"glyph":{"id":"69f669e1-499d-490e-a444-35f8345747b3","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"0d7472d3-8ee5-4fc1-8ea3-8fbfac96b59b","type":"GlyphRenderer"},{"attributes":{},"id":"c251ba3a-be19-42b1-873b-91eabd0180f4","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"TEAM_NAME":["BAL"],"chart_index":[{"TEAM_NAME":"BAL"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[161.0],"label":[{"TEAM_NAME":"BAL"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["BAL"],"y":[80.5]}},"id":"3 ...

# %% [markdown]
# # DIVIDE STAT BY STAT AND PLOT DISTRIBUTION AS HISTOGRAM
#
#     > tuple[0] takes 1 column and divides it by another column
#     > tuple[1] filters  tuple[0] column by "> tuple[1]"
#     > team path is path to location on computer where batting csvs are stored
#
#     > What do the next two graphs show?
#         > In 2016 it took most players more plate appearances (At Bats) to hit a Home Run (HR)

# %%
f1 = ('AB', 20)
s1 = ('HR', 5)
team_path = ''
table_scraper.stat_divided_by_stat(team_path, f1,s1, 2014, bins_int=8)
# Out:
# /Users/Anthony/Desktop/git_notebooks_clean/Python_projects/web-scraping/baseball_analysis.py:525: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   years_df1[new_col_name] = years_df1[first_stat_tup[0]] / years_df1[second_stat_tup[0]]
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e96f0bb9-3632-48d7-a9b6-8fbbbb1e8962"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("e96f0bb9-3632-48d7-a9b6-8fbbbb1e8962").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e96f0bb9-3632-48d7-a9b6-8fbbbb1e8962");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e96f0bb9-3632-48d7-a9b6-8fbbbb1e8962' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ab671725-4353-4ae1-ab9c-1a369b590257":{"roots":{"references":[{"attributes":{"data_source":{"id":"5745cde1-8970-4c17-92f7-dbb0a233a366","type":"ColumnDataSource"},"glyph":{"id":"cb662bc5-8487-454b-8459-8e795a617944","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"5a79cf43-0ac4-493c-9756-3c8b386964c6","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"25c00cdd-10ac-494c-a90c-0f84b26c3882","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"cb662bc5-8487-454b-8459-8e795a617944","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(43.375000, 53.500000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[24.0],"label":["(43.375000, 53.500000]"],"line_alpha":[1.0],"line_color":["black"],"width":[10.125],"x":["48.4375"],"y":[12.0]}},"id":"5745cde1-8970-4c17-92f7-dbb0a233a366","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"d2f5997f-dbf7-4a22-b2fa-cd53c7a84b7d","type":"ColumnDataSource"},"glyph":{"id":"57a2f43b-6adb-4dd2-b249-79ab46a50f51","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"6b35f850-d489-4e3e-9099-37474bfbfb32","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"816ca70a-9efd-4263-aba8-666c7079c7b1","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(63.625000, 73.750000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[10.0],"label":["(63.625000, 73.750000]"],"line_alpha":[1.0],"line_color":["black"],"width":[10.125],"x":["68.6875"],"y":[5.0]}},"id":"65a74f58-45a4-44a2-bae2-aaafd74353d1","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(83.875000, 94.000000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[6.0],"label":["(83.875000, 94.000000]"],"line_alpha":[1.0],"line_color":["black"],"width":[10.125],"x":["88.9375"],"y":[3.0]}},"id":"b457ffa7-f9e2-42ac-88e0-a0c25488adbf","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"57a2f43b-6adb-4dd2-b249-79ab46a50f51","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(73.750000, 83.875000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[5.0],"label":["(73.750000, 83.875000]"],"line_alpha":[1.0],"line_color":["black"],"width":[10.125],"x":["78.8125"],"y":[2.5]}},"id":"e44ce56b-c466-4391-af86-22fb29b4f13c","type":"ColumnDataSource"},{"attributes":{},"id":"315d678a-fe24-44e2-bcf2-9a7079448a03","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(33.250000, 43.375000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[69.0],"label":["(33.250000, 43.375000]"],"line_alpha":[1.0],"line_color":["black"],"width ...

# %%
f1 = ('AB', 20)
s1 = ('HR', 5)
team_path = ''
table_scraper.stat_divided_by_stat(team_path, f1,s1, 2016, bins_int=12)
# Out:
# /Users/Anthony/Desktop/git_notebooks_clean/Python_projects/web-scraping/baseball_analysis.py:525: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   years_df1[new_col_name] = years_df1[first_stat_tup[0]] / years_df1[second_stat_tup[0]]
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0aa2fc44-f14c-4979-85a4-381b367ffa3e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("0aa2fc44-f14c-4979-85a4-381b367ffa3e").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0aa2fc44-f14c-4979-85a4-381b367ffa3e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0aa2fc44-f14c-4979-85a4-381b367ffa3e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"849f0e66-9084-41c0-ad6f-aec68c62c481":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2fbd3c22-4601-47c6-8b3a-16522bc03ae6","type":"Rect"},{"attributes":{"data_source":{"id":"4e41ac05-e894-4a53-a235-2481aafab859","type":"ColumnDataSource"},"glyph":{"id":"4545e7d2-7ba0-4525-9d93-292600a7e607","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"9539ca4e-1d8f-4e29-a1b0-4d5f11c28091","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(84.250000, 91.000000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[2.0],"label":["(84.250000, 91.000000]"],"line_alpha":[1.0],"line_color":["black"],"width":[6.75],"x":["87.625"],"y":[1.0]}},"id":"f7f3e3af-4b46-4761-a643-ffe6e0d16a13","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"477782bb-0b91-48d5-9ae0-997a3cca9ca4","subtype":"Chart","type":"Plot"}},"id":"cdd967e8-a5ea-44d7-81e0-46cfe94c189d","type":"WheelZoomTool"},{"attributes":{"axis_label":"AB_HR","formatter":{"id":"607aa91b-c1f5-4c77-ba64-13cd063c095e","type":"BasicTickFormatter"},"plot":{"id":"477782bb-0b91-48d5-9ae0-997a3cca9ca4","subtype":"Chart","type":"Plot"},"ticker":{"id":"8a8a0f86-65cb-442f-a4f5-1a6e05e64321","type":"BasicTicker"}},"id":"9242900e-0efa-43e7-8eba-4d265fe7c0e4","type":"LinearAxis"},{"attributes":{"overlay":{"id":"2521eb2c-be7f-496b-9a07-ef6969e67f66","type":"BoxAnnotation"},"plot":{"id":"477782bb-0b91-48d5-9ae0-997a3cca9ca4","subtype":"Chart","type":"Plot"}},"id":"fce796e9-f486-4707-a04d-b75479e1f07a","type":"BoxZoomTool"},{"attributes":{"data_source":{"id":"27c0c2ba-4590-4d37-95ba-06b08414bd98","type":"ColumnDataSource"},"glyph":{"id":"e0d60969-f9f6-4e66-9e4e-da59d041c632","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"b84f4379-bd27-49d2-8ca8-255b09595e1b","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"477782bb-0b91-48d5-9ae0-997a3cca9ca4","subtype":"Chart","type":"Plot"}},"id":"15302a70-b6de-4b04-a874-bdde7a4e3d28","type":"SaveTool"},{"attributes":{"plot":{"id":"477782bb-0b91-48d5-9ae0-997a3cca9ca4","subtype":"Chart","type":"Plot"}},"id":"a3d81b23-eece-4983-8d16-a2f22ba3ba8f","type":"ResetTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"83f258d5-0ad3-4325-b8d7-34f4745e9a83","type":"Rect"},{"attributes":{},"id":"9c59998f-d058-4965-a040-629590af4bf7","type":"BasicTicker"},{"attributes":{},"id":"8a8a0f86-65cb-442f-a4f5-1a6e05e64321","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"477782bb-0b91-48d5-9ae0-997a3cca9ca4","subtype":"Chart","type":"Plot"},"ticker":{"id":"9c59998f-d058-4965-a040-629590af4bf7","type":"BasicTicker"}},"id":"3e72230c-04ec-438c-91c8-8e2b124e1af5","type":"Grid"},{"attributes":{"data_source":{"id":"f7f3e3af-4b46-4761-a643-ffe6e0d16a13","type":"ColumnDataSource"},"glyph":{"id":"a0d64735-cc00-4d11-8596-7e36c46f19ff","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"3925ae6a-54c6-4a55-bee1-ecc10e5833e1","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4545e7d2-7ba0-4525-9d93-292600a7e607","type":"Rect"},{"attributes":{},"id":"607aa91b-c1f5-4c77-ba64-13cd063c095e","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"5ed00d1b-bd34-4852-b825-d072c4f785d9","t ...

# %% [markdown]
# # SCATTERPLOT
#     > get column names
#     > salaries dfs & team dfs indexed on team, name, year are merged and players w/o salaries are dropped
#
#     > What this graph shows:
#         > Players that made greater than $10 million but less than $20 million that played at least 20 gamesin 2017

# %%
sal_path = ''
team_path = ''
merged_sal = table_scraper.merge_dfs(sal_path, team_path, 2017)

table_scraper.scatterplot_salary(merged_sal,10000000, 20000000, ('G', 20))
#table_scraper.scatterplot_salary(merged_sal,1000000, 10000000, ('G', 20), get_plot_df=True)
# Out:
# /Applications/anaconda/lib/python3.6/site-packages/bokeh/models/sources.py:81: BokehUserWarning: ColumnDataSource's columns must be of the same length
#   lambda: warnings.warn("ColumnDataSource's columns must be of the same length", BokehUserWarning))
# /Applications/anaconda/lib/python3.6/site-packages/bokeh/models/sources.py:81: BokehUserWarning: ColumnDataSource's columns must be of the same length
#   lambda: warnings.warn("ColumnDataSource's columns must be of the same length", BokehUserWarning))
# /Applications/anaconda/lib/python3.6/site-packages/bokeh/models/sources.py:81: BokehUserWarning: ColumnDataSource's columns must be of the same length
#   lambda: warnings.warn("ColumnDataSource's columns must be of the same length", BokehUserWarning))
# /Applications/anaconda/lib/python3.6/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning: Setting Plot property 'title' using a string was deprecated in 0.12.0,
#             and will be removed. The title is now an object on Plot (which holds all of it's
#             styling properties). Please use Plot.title.text instead.
#
#             SERVER USERS: If you were using plot.title to have the server update the plot title
#             in a callback, you MUST update to plot.title.text as the title object cannot currently
#             be replaced after initialization.
#
#   warn(message)
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e800a1b2-4c59-4201-a30d-eddfbe2d68b0"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("e800a1b2-4c59-4201-a30d-eddfbe2d68b0").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e800a1b2-4c59-4201-a30d-eddfbe2d68b0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e800a1b2-4c59-4201-a30d-eddfbe2d68b0' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6ef034b2-c367-408e-92fa-a798959f6223":{"roots":{"references":[{"attributes":{"below":[{"id":"d611567c-4e8e-4a5a-aa9a-bfdb6c83f9e9","type":"LinearAxis"}],"left":[{"id":"66600a39-c191-4b2b-a00f-54b9361233b2","type":"LinearAxis"}],"plot_height":500,"plot_width":650,"renderers":[{"id":"d611567c-4e8e-4a5a-aa9a-bfdb6c83f9e9","type":"LinearAxis"},{"id":"c393454c-065c-4d60-bcb1-f070e0605855","type":"Grid"},{"id":"66600a39-c191-4b2b-a00f-54b9361233b2","type":"LinearAxis"},{"id":"6269cc07-271d-4fca-8348-49f9053db712","type":"Grid"},{"id":"a7f2d5a9-e16d-4f99-9f99-7275581837cd","type":"GlyphRenderer"}],"title":{"id":"cce2ef41-9518-4ff5-8111-27c0ca1c5a3b","type":"Title"},"tool_events":{"id":"3fbb9c08-0586-4a9b-99a0-9d42461995c0","type":"ToolEvents"},"toolbar":{"id":"ad9fdf3d-a20a-40f2-bd05-badd7216aecc","type":"Toolbar"},"x_range":{"id":"d8dbc00b-7dc4-4904-b7a2-d398a0ff9236","type":"DataRange1d"},"y_range":{"id":"df9eac49-3d2e-4dc1-99ef-818c4de198b8","type":"DataRange1d"}},"id":"9cf23e33-b1d8-4610-8558-94dc1ab0ad21","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"11a6c496-d617-4667-9b1e-93e48203efe4","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"9cf23e33-b1d8-4610-8558-94dc1ab0ad21","subtype":"Figure","type":"Plot"},"ticker":{"id":"54de785f-ec06-49af-973f-edbfeb8f17c4","type":"BasicTicker"}},"id":"c393454c-065c-4d60-bcb1-f070e0605855","type":"Grid"},{"attributes":{"plot":null,"text":"Salary vs G          n= 57"},"id":"cce2ef41-9518-4ff5-8111-27c0ca1c5a3b","type":"Title"},{"attributes":{"dimension":1,"plot":{"id":"9cf23e33-b1d8-4610-8558-94dc1ab0ad21","subtype":"Figure","type":"Plot"},"ticker":{"id":"65d83031-7fbb-4966-b47d-402175f91c72","type":"BasicTicker"}},"id":"6269cc07-271d-4fca-8348-49f9053db712","type":"Grid"},{"attributes":{},"id":"54de785f-ec06-49af-973f-edbfeb8f17c4","type":"BasicTicker"},{"attributes":{},"id":"3fbb9c08-0586-4a9b-99a0-9d42461995c0","type":"ToolEvents"},{"attributes":{"callback":null},"id":"df9eac49-3d2e-4dc1-99ef-818c4de198b8","type":"DataRange1d"},{"attributes":{"callback":null},"id":"d8dbc00b-7dc4-4904-b7a2-d398a0ff9236","type":"DataRange1d"},{"attributes":{"callback":null,"plot":{"id":"9cf23e33-b1d8-4610-8558-94dc1ab0ad21","subtype":"Figure","type":"Plot"},"tooltips":[["Player"," @desc"],["POS"," @desc1"],["SALARY"," @desc2"],["TEAM"," @desc3"]]},"id":"91abba67-6108-46bd-98ca-924b3cf95e68","type":"HoverTool"},{"attributes":{"axis_label":"Salary","formatter":{"id":"11a6c496-d617-4667-9b1e-93e48203efe4","type":"BasicTickFormatter"},"plot":{"id":"9cf23e33-b1d8-4610-8558-94dc1ab0ad21","subtype":"Figure","type":"Plot"},"ticker":{"id":"65d83031-7fbb-4966-b47d-402175f91c72","type":"BasicTicker"}},"id":"66600a39-c191-4b2b-a00f-54b9361233b2","type":"LinearAxis"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"black"},"line_alpha":{"value":0.5},"line_color":{"value":"white"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"7ec73c95-7db0-4485-a7d3-3ecfbced1fd2","type":"Circle"},{"attributes":{"axis_label":"G","formatter":{"id":"250f68c1-3c04-4385-b6f8-91674b056e59","type":"BasicTickFormatter"},"plot":{"id":"9cf23e33-b1d8-4610-8558-94dc1ab0ad21","subtype":"Figure","type":"Plot"},"ticker":{"id":"54de785f-ec06-49af-973f-edbfeb8f17c4","type":"BasicTicker"}},"id":"d611567c-4e8e-4a5a-aa9a-bfdb6c83f9e9","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"91abba67-6108-46bd-98ca-924b3cf95e68","type":"HoverTool"}]},"id":"ad9fdf3d-a20a-40f2-bd05-badd7216aecc","type":"Toolbar"},{"attributes":{},"id":"250f68c1-3c04-4385-b6f8-91674b056e59","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x","y","desc","desc1","desc2","desc3"],"data":{"desc":["Brandon Phillips","Nick Markakis","Manny Machado","Adam Jones","Zach Britton","Pablo Sandoval","Chris Sale","Craig Kimbrel","Ben Zobrist","Miguel Montero","Jake Arrieta","John Lackey","Todd Frazier","Melky C ...
